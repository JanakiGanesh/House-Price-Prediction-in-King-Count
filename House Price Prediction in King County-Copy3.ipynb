# %% [markdown]
# #                               House Price Prediction in King County

# %% [markdown]
# ![image info](./images/high-angle-view-of-suburban-houses-ip-galanternik-du.jpg)

# %% [markdown]
# ## Overview

# %% [markdown]
# This project focus on predicting the house price given various factors affecting the price. It involves investigation of house sales in the King County area and building a multiple linear regression model to predict the sale price.

# %% [markdown]
# ## Business Problem

# %% [markdown]
# Homeowners approaches the real estate agency for help in order to buy /sell their homes. The business problem that we could focus on for the real estate agency is the need to provide advice to homeowners about home renovations that might increase the estimated value of their homes, and by what amount. In this project we are providing the prediction data to the real estate agency for homeowners who wants to buy homes. It focus on the factors that increases the house price that might be negotiated while purchasing new homes.

# %% [markdown]
# ## Approach and methodology

# %% [markdown]
# In this project we are following OSEMN data science workflow. It contains:
# * Obtain (Generate data)
# * Scrub (extracting columns,handling missing values)
# * Explore (understanding data and create visualization)
# * Model (building regression model)
# * Interpret (communicating results)

# %% [markdown]
# ## OBTAIN

# %%
# import all the needed packages
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('seaborn')
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %% [markdown]
# Load the csv file into a dataframe

# %%
df = pd.read_csv('data/kc_house_data.csv')

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0     1955           0.0    98178  47.5112 -122.257           1340        5650
# 1     1951        1991.0    98125  47.7210 -122.319           1690        7639
# 2     1933           NaN    98028  47.7379 -122.233           2720        8062
# 3     1965           0.0    98136  47.5208 -122.393           1360        5000
# 4     1987           0.0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ## SCRUB

# %% [markdown]
# This involes extracting columns and cleaning data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
# convert 'date' to datetime object.
df['date'] = df.date.apply(pd.Timestamp)

# %%
df['date']
# Out:
# 0       2014-10-13
# 1       2014-12-09
# 2       2015-02-25
# 3       2014-12-09
# 4       2015-02-18
#            ...
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21595   2015-01-16
# 21596   2014-10-15
# Name: date, Length: 21597, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null datetime64[ns]
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: datetime64[ns](1), float64(8), int64(11), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# Few columns have null values.

# %%
# checking for null values in watefront column
df['waterfront'].isna().any()
# Out:
# True

# %%
df['waterfront'].unique()
# Out:
# array([nan,  0.,  1.])

# %%
df['waterfront'].isna().sum()/len(df['waterfront'])
# Out:
# 0.11001527989998611

# %% [markdown]
# Since null value contributes 11%, we will consider it has 0 (no waterfront)

# %%
# Replacing the null values with '0'
df['waterfront'].fillna(0, inplace=True)

# %%
df['waterfront'].unique()
# Out:
# array([0., 1.])

# %%
df['view'].isna().any()
# Out:
# True

# %%
df['view'].unique()
# Out:
# array([ 0., nan,  3.,  4.,  2.,  1.])

# %%
# Replacing the null values with '0'
df['view'].fillna(0, inplace = True)

# %%
df['view'].unique()
# Out:
# array([0., 3., 4., 2., 1.])

# %%
df['condition'].unique()
# Out:
# array([3, 5, 4, 1, 2])

# %%
df['grade'].unique()
# Out:
# array([ 7,  6,  8, 11,  9,  5, 10, 12,  4,  3, 13])

# %%
df['yr_renovated'].isna().any()
# Out:
# True

# %%
# Replacing the null values with '0'
df['yr_renovated'].fillna(0, inplace = True)

# %%
df['yr_renovated'].unique()
# Out:
# array([   0., 1991., 2002., 2010., 1992., 2013., 1994., 1978., 2005.,
#        2003., 1984., 1954., 2014., 2011., 1983., 1945., 1990., 1988.,
#        1977., 1981., 1995., 2000., 1999., 1998., 1970., 1989., 2004.,
#        1986., 2007., 1987., 2006., 1985., 2001., 1980., 1971., 1979.,
#        1997., 1950., 1969., 1948., 2009., 2015., 1974., 2008., 1968.,
#        2012., 1963., 1951., 1962., 1953., 1993., 1996., 1955., 1982.,
#        1956., 1940., 1976., 1946., 1975., 1964., 1973., 1957., 1959.,
#        1960., 1967., 1965., 1934., 1972., 1944., 1958.])

# %%
df['sqft_basement'].dtype
# Out:
# dtype('O')

# %% [markdown]
# 'sqft_basement' column is in object and needs to be converted to float.

# %%
df['sqft_basement'].unique()
# Out:
# array(['0.0', '400.0', '910.0', '1530.0', '?', '730.0', '1700.0', '300.0',
#        '970.0', '760.0', '720.0', '700.0', '820.0', '780.0', '790.0',
#        '330.0', '1620.0', '360.0', '588.0', '1510.0', '410.0', '990.0',
#        '600.0', '560.0', '550.0', '1000.0', '1600.0', '500.0', '1040.0',
#        '880.0', '1010.0', '240.0', '265.0', '290.0', '800.0', '540.0',
#        '710.0', '840.0', '380.0', '770.0', '480.0', '570.0', '1490.0',
#        '620.0', '1250.0', '1270.0', '120.0', '650.0', '180.0', '1130.0',
#        '450.0', '1640.0', '1460.0', '1020.0', '1030.0', '750.0', '640.0',
#        '1070.0', '490.0', '1310.0', '630.0', '2000.0', '390.0', '430.0',
#        '850.0', '210.0', '1430.0', '1950.0', '440.0', '220.0', '1160.0',
#        '860.0', '580.0', '2060.0', '1820.0', '1180.0', '200.0', '1150.0',
#        '1200.0', '680.0', '530.0', '1450.0', '1170.0', '1080.0', '960.0',
#        '280.0', '870.0', '1100.0', '460.0', '1400.0', '660.0', '1220.0',
#        '900.0', '420.0', '1580.0', '1380.0', '475.0', '690.0', '270.0',
#        '350.0', '935.0', '1370.0', '980.0', '1470.0', '160.0', '950.0',
#        '50.0', '740.0', '1780.0', '1900.0', '340.0', '470.0', '370.0',
#        '140.0', '1760.0', '130.0', '520.0', '890.0', '1110.0', '150.0',
#        '1720.0', '810.0', '190.0', '1290.0', '670.0', '1800.0', '1120.0',
#        '1810.0', '60.0', '1050.0', '940.0', '310.0', '930.0', '1390.0',
#        '610.0', '1830.0', '1300.0', '510.0', '1330.0', '1590.0', '920.0',
#        '1320.0', '1420.0', '1240.0', '1960.0', '1560.0', '2020.0',
#        '1190.0', '2110.0', '1280.0', '250.0', '2390.0', '1230.0', '170.0',
#        '830.0', '1260.0', '1410.0', '1340.0', '590.0', '1500.0', '1140.0',
#        '260.0', '100.0', '320.0', '1480.0', '1060.0', '1284.0', '1670.0',
#        '1350.0', '2570.0', '1090.0', '110.0', '2500.0', '90.0', '1940.0',
#        '1550.0', '2350.0', '2490.0', '1481.0', '1360.0', '1135.0',
#        '1520.0', '1850.0', '1660.0', '2130.0', '2600.0', '1690.0',
#        '243.0', '1210.0', '1024.0', '1798.0', '1610.0', '1440.0',
#        '1570.0', '1650.0', '704.0', '1910.0', '1630.0', '2360.0',
#        '1852.0', '2090.0', '2400.0', '1790.0', '2150.0', '230.0', '70.0',
#        '1680.0', '2100.0', '3000.0', '1870.0', '1710.0', '2030.0',
#        '875.0', '1540.0', '2850.0', '2170.0', '506.0', '906.0', '145.0',
#        '2040.0', '784.0', '1750.0', '374.0', '518.0', '2720.0', '2730.0',
#        '1840.0', '3480.0', '2160.0', '1920.0', '2330.0', '1860.0',
#        '2050.0', '4820.0', '1913.0', '80.0', '2010.0', '3260.0', '2200.0',
#        '415.0', '1730.0', '652.0', '2196.0', '1930.0', '515.0', '40.0',
#        '2080.0', '2580.0', '1548.0', '1740.0', '235.0', '861.0', '1890.0',
#        '2220.0', '792.0', '2070.0', '4130.0', '2250.0', '2240.0',
#        '1990.0', '768.0', '2550.0', '435.0', '1008.0', '2300.0', '2610.0',
#        '666.0', '3500.0', '172.0', '1816.0', '2190.0', '1245.0', '1525.0',
#        '1880.0', '862.0', '946.0', '1281.0', '414.0', '2180.0', '276.0',
#        '1248.0', '602.0', '516.0', '176.0', '225.0', '1275.0', '266.0',
#        '283.0', '65.0', '2310.0', '10.0', '1770.0', '2120.0', '295.0',
#        '207.0', '915.0', '556.0', '417.0', '143.0', '508.0', '2810.0',
#        '20.0', '274.0', '248.0'], dtype=object)

# %%
df['sqft_basement'].str.contains(' ?')
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 21592    True
# 21593    True
# 21594    True
# 21595    True
# 21596    True
# Name: sqft_basement, Length: 21597, dtype: bool

# %%
# replacing the string character to 0 and converting to float
df['sqft_basement'] = df['sqft_basement'].replace('?', 0).astype(float)

# %%
df['sqft_basement'].unique()
# Out:
# array([   0.,  400.,  910., 1530.,  730., 1700.,  300.,  970.,  760.,
#         720.,  700.,  820.,  780.,  790.,  330., 1620.,  360.,  588.,
#        1510.,  410.,  990.,  600.,  560.,  550., 1000., 1600.,  500.,
#        1040.,  880., 1010.,  240.,  265.,  290.,  800.,  540.,  710.,
#         840.,  380.,  770.,  480.,  570., 1490.,  620., 1250., 1270.,
#         120.,  650.,  180., 1130.,  450., 1640., 1460., 1020., 1030.,
#         750.,  640., 1070.,  490., 1310.,  630., 2000.,  390.,  430.,
#         850.,  210., 1430., 1950.,  440.,  220., 1160.,  860.,  580.,
#        2060., 1820., 1180.,  200., 1150., 1200.,  680.,  530., 1450.,
#        1170., 1080.,  960.,  280.,  870., 1100.,  460., 1400.,  660.,
#        1220.,  900.,  420., 1580., 1380.,  475.,  690.,  270.,  350.,
#         935., 1370.,  980., 1470.,  160.,  950.,   50.,  740., 1780.,
#        1900.,  340.,  470.,  370.,  140., 1760.,  130.,  520.,  890.,
#        1110.,  150., 1720.,  810.,  190., 1290.,  670., 1800., 1120.,
#        1810.,   60., 1050.,  940.,  310.,  930., 1390.,  610., 1830.,
#        1300.,  510., 1330., 1590.,  920., 1320., 1420., 1240., 1960.,
#        1560., 2020., 1190., 2110., 1280.,  250., 2390., 1230.,  170.,
#         830., 1260., 1410., 1340.,  590., 1500., 1140.,  260.,  100.,
#         320., 1480., 1060., 1284., 1670., 1350., 2570., 1090.,  110.,
#        2500.,   90., 1940., 1550., 2350., 2490., 1481., 1360., 1135.,
#        1520., 1850., 1660., 2130., 2600., 1690.,  243., 1210., 1024.,
#        1798., 1610., 1440., 1570., 1650.,  704., 1910., 1630., 2360.,
#        1852., 2090., 2400., 1790., 2150.,  230.,   70., 1680., 2100.,
#        3000., 1870., 1710., 2030.,  875., 1540., 2850., 2170.,  506.,
#         906.,  145., 2040.,  784., 1750.,  374.,  518., 2720., 2730.,
#        1840., 3480., 2160., 1920., 2330., 1860., 2050., 4820., 1913.,
#          80., 2010., 3260., 2200.,  415., 1730.,  652., 2196., 1930.,
#         515.,   40., 2080., 2580., 1548., 1740.,  235.,  861., 1890.,
#        2220.,  792., 2070., 4130., 2250., 2240., 1990.,  768., 2550.,
#         435., 1008., 2300., 2610.,  666., 3500.,  172., 1816., 2190.,
#        1245., 1525., 1880.,  862.,  946., 1281.,  414., 2180.,  276.,
#        1248.,  602.,  516.,  176.,  225., 1275.,  266.,  283.,   65.,
#        2310.,   10., 1770., 2120.,  295.,  207.,  915.,  556.,  417.,
#         143.,  508., 2810.,   20.,  274.,  248.])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null datetime64[ns]
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       21597 non-null float64
# view             21597 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null float64
# yr_built         21597 non-null int64
# yr_renovated     21597 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: datetime64[ns](1), float64(9), int64(11)
# memory usage: 3.5 MB

# %%
# converting zipcode from integer to string
df['zipcode'] = df['zipcode'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null datetime64[ns]
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       21597 non-null float64
# view             21597 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null float64
# yr_built         21597 non-null int64
# yr_renovated     21597 non-null float64
# zipcode          21597 non-null object
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: datetime64[ns](1), float64(9), int64(10), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ## Explore

# %% [markdown]
# Let's create visualization and check the distribution each columns

# %%
# create histogram for each column
df.hist(figsize = (18, 15), bins = 'auto');

# %%
# create pairplot for each column
sns.pairplot(df)

# %%
# create scatter plot for each column
sm = pd.plotting.scatter_matrix(df, figsize = [20, 20]);

# Rotates the text
[s.xaxis.label.set_rotation(90) for s in sm.reshape(-1)]
[s.yaxis.label.set_rotation(0) for s in sm.reshape(-1)]

#May need to offset label when rotating to prevent overlap of figure
[s.get_yaxis().set_label_coords(-1, 0.5) for s in sm.reshape(-1)]

#Hide all ticks
[s.set_xticks(()) for s in sm.reshape(-1)]
[s.set_yticks(()) for s in sm.reshape(-1)]

plt.show()

# %%
# removing 'id' column 
df.drop('id', axis = 1, inplace = True)

# %% [markdown]
# Let us plot heat map to check for the multicolinearity

# %%
# heat map
corr = df.corr().abs()
fig, ax = plt.subplots(figsize = (17, 12))
fig.suptitle('Variable Correlations', fontsize = 30, y = .95, fontname = 'Silom')
heatmap = sns.heatmap(corr, cmap = 'Reds', annot = True)
corr
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308787   0.525906     0.701917  0.089876  0.256804
# bedrooms       0.308787  1.000000   0.514508     0.578212  0.032471  0.177944
# bathrooms      0.525906  0.514508   1.000000     0.755758  0.088373  0.502582
# sqft_living    0.701917  0.578212   0.755758     1.000000  0.173453  0.353953
# sqft_lot       0.089876  0.032471   0.088373     0.173453  1.000000  0.004814
# floors         0.256804  0.177944   0.502582     0.353953  0.004814  1.000000
# waterfront     0.264306  0.002127   0.063629     0.104637  0.021459  0.020797
# view           0.393497  0.078354   0.186016     0.281715  0.075054  0.028414
# condition      0.036056  0.026496   0.126479     0.059445  0.008830  0.264075
# grade          0.667951  0.356563   0.665838     0.762779  0.114731  0.458794
# sqft_above     0.605368  0.479386   0.686668     0.876448  0.184139  0.523989
# sqft_basement  0.321108  0.297229   0.278485     0.428660  0.015031  0.241866
# yr_built       0.053953  0.155670   0.507173     0.318152  0.052946  0.489193
# yr_renovated   0.117855  0.017900   0.047177     0.051060  0.004979  0.003793
# lat            0.306692  0.009951   0.024280     0.052155  0.085514  0.049239
# long           0.022036  0.132054   0.224903     0.241214  0.230227  0.125943
# sqft_living15  0.585241  0.393406   0.569884     0.756402  0.144763  0.280102
# sqft_lot15     0.082845  0.030690   0.088303     0.184342  0.718204  0.010722
#
#                waterfront      view  condition     grade  sqft_above  \
# price            0.264306  0.393497   0.036056  0.667951    0.605368
# bedrooms         0.002127  0.078354   0.026496  0.356563    0.479386
# bathrooms        0.063629  0.186016   0.126479  0.665838    0.686668
# sqft_living      0.104637  0.281715   0.059445  0.762779    0.876448
# sqft_lot         0.021459  0.075054   0.008830  0.114731    0.184139
# floors           0.020797  0.028414   0.264075  0.458794    0.523989
# waterfront       1.000000  0.380543   0.016648  0.082818    0.071778
# view             0.380543  1.000000   0.045622  0.249082    0.166017
# condition        0.016648  0.045622   1.000000  0.146896    0.158904
# grade            0.082818  0.249082   0.146896  1.000000    0.756073
# sqft_above       0.071778  0.166017   0.158904  0.756073    1.000000
# sqft_basement    0.083050  0.270629   0.168482  0.165843    0.051175
# yr_built         0.024487  0.054452   0.361592  0.447865    0.424037
# yr_renovated     0.073939  0.090339   0.055808  0.015623    0.020645
# lat              0.012157  0.006321   0.015102  0.113575    0.001199
# long             0.037628  0.077702   0.105877  0.200341    0.344842
# sqft_living15    0.083823  0.278928   0.093072  0.713867    0.731767
# sqft_lot15       0.030658  0.073083   0.003126  0.120981    0.195077
#
#                sqft_basement  yr_built  yr_renovated       lat      long  \
# price               0.321108  0.053953      0.117855  0.306692  0.022036
# bedrooms            0.297229  0.155670      0.017900  0.009951  0.132054
# bathrooms           0.278485  0.507173      0.047177  0.024280  0.224903
# sqft_living         0.428660  0.318152      0.051060  0.052155  0.241214
# sqft_lot            0.015031  0.052946      0.004979  0.085514  0.230227
# floors              0.241866  0.489193      0.003793  0.049239  0.125943
# waterfront          0.083050  0.024487      0.073939  0.012157  0.037628
# view                0.270629  0.054452      0.090339  0.006321  0.077702
# condition           0.168482  0.361592      0.055808  0.015102  0.105877
# grade               0.165843  0.447865      0.015623  0.113575  0.200341
# sqft_above          0.051175  0.424037      0.020645  0.001199  0.344842
# sqft_basement       1.000000  0.130085      0.065008  0.109853  0.142369
# yr_built            0.130085  1.000000      0.202555  0.148370  0.409993
# yr_renovated        0.065008  0.202555      1.000000  0.027970  0.064543
# lat                 0.109853  0.148370      0.027970  1.000000  0.135371
# long                0.142369  0.409993      0.064543  0.135371  1.000000
# sqft_living15       0.199288  0.326377      0.000683  0.048679  0.335626
# sqft_lot15          0.015885  0.070777      0.004286  0.086139  0.255586
#
#                sqft_living15  sqft_lot15
# price               0.585241    0.082845
# bedrooms            0.393406    0.030690
# bathrooms           0.569884    0.088303
# sqft_living         0.756402    0.184342
# sqft_lot            0.144763    0.718204
# floors              0.280102    0.010722
# waterfront          0.083823    0.030658
# view                0.278928    0.073083
# condition           0.093072    0.003126
# grade               0.713867    0.120981
# sqft_above          0.731767    0.195077
# sqft_basement       0.199288    0.015885
# yr_built            0.326377    0.070777
# yr_renovated        0.000683    0.004286
# lat                 0.048679    0.086139
# long                0.335626    0.255586
# sqft_living15       1.000000    0.183515
# sqft_lot15          0.183515    1.000000

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# Based on the heat map, I have taken few columns which is having linear property with the 'price'

# %%
df1 = df[['sqft_living', 'grade', 'sqft_lot', 'sqft_above', 'sqft_living15', 'view', 'bathrooms', 'bedrooms']]

# %% [markdown]
# ## Model

# %% [markdown]
# Now let's create a baseline multiple linear regression model with the selected columns. Here we are using the Scikit learn model for our project.

# %% [markdown]
# ### Model 1

# %%
# splitting the data into train and test 
X = df1
y = df['price']

# %% [markdown]
# Now using the scikit learn transform the data into train and test data with 75% of training data and 25% of test data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %% [markdown]
# Let's define a function for linear regression to scale,transform,fit and predict the 'Root mean squared error' and 'R-squared value'

# %%
# Linear regression function
def linear_model(X_train, y_train, X_test, y_test):
#   Scaling the data
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train_scaled = scaler.transform(X_train)
    X_test_scaled = scaler.transform(X_test)
#   Create model 
    lr = LinearRegression()
#   Fit the train data in the model
    lr.fit(X_train_scaled, y_train)
#   Predict the train and test data
    train_pred = lr.predict(X_train_scaled)
    test_pred = lr.predict(X_test_scaled)
#   Finding RMSE value for the train and test data
    train_rmse = np.sqrt(mean_squared_error(y_train, (train_pred)))
    test_rmse = np.sqrt(mean_squared_error(y_test, (test_pred)))
    print("Train RMSE: "+ str(train_rmse))
    print("Test RMSE: "+ str(test_rmse))
#   Finding the R2 value for the train and test data  
    train_r_squared = r2_score(y_train, train_pred)
    test_r_squared = r2_score(y_test, test_pred)
    print("Train R2: "+ str(train_r_squared))
    print("Test R2: "+ str(test_r_squared))
#   Finding MAE value for the train and test data  
    residuals_train = y_train - train_pred
    residuals_test = y_test - test_pred
    train_mae = np.mean(abs(residuals_train))
    test_mae = np.mean(abs(residuals_test))
    print("Train MAE: "+ str(train_mae))
    print("Test MAE: "+ str(test_mae))
    sns.regplot(x=  test_pred, y = y_test)
    plt.ylabel('Price')

# %%
linear_model(X_train,y_train,X_test,y_test)
# Out:
# Train RMSE: 236467.87482500693
# Test RMSE: 242081.30788978518
# Train R2: 0.5833310228392444
# Test R2: 0.5728609089897383
# Train MAE: 155435.64496542394
# Test MAE: 154512.45694916268

# %% [markdown]
# Multiple Linear Regression Assumptions:
# * No multicollinearity
# * No heteroscedasticity
# * No non linear relationship between target and response variable
# * No normality checks

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
lr = LinearRegression()
lr.fit(X_train_scaled, y_train)
train_pred = lr.predict(X_train_scaled)
test_pred = lr.predict(X_test_scaled)

# %%
# Calculating train and test data residuals
residuals_train = y_train - train_pred
residuals_test = y_test - test_pred

# %%
# heteroscadacity check
plt.scatter(train_pred, residuals_train, alpha = .75)
plt.scatter(test_pred, residuals_test, color = 'g', alpha = .75)
plt.axhline(y = 0, color = 'black')
plt.title('Residuals for Linear Regression Model')
plt.ylabel('Residuals')
plt.xlabel('Predicted Values')
plt.show()

# %%
# QQ-plot to check for the normal distribution.
ax1 = plt.subplot(221)
res = stats.probplot(residuals_train, plot = plt)

# %%
ax2 = plt.subplot(222)
res = stats.probplot(residuals_test, plot=plt)

# %% [markdown]
# Our baseline model is heteroscedastic and not normally distributed. hence we need to improve our model to satisfy the linear regression assumptions.

# %% [markdown]
# ### Model 2

# %%
# Based on the strenth of the correlation ,I have chosen few columns
df2 = df[['price', 'sqft_living', 'grade', 'sqft_lot', 'sqft_above', 'sqft_living15', 'view', 'bathrooms', 'bedrooms', 'condition']]
y = df2['price']
X = df2.drop(['price'], axis = 1)
for val in X.columns:
    sns.regplot(x = val, y = 'price', data = df2); 
    plt.show()

# %% [markdown]
# On seeing the graph above, Let us select the column that are linear with price

# %%
df3 = df[['sqft_living', 'grade', 'sqft_above', 'sqft_living15', 'view', 'bathrooms', 'price']]

# %% [markdown]
# Splitting our train and test data

# %%
y = df3['price']
X = df3.drop('price',axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
linear_model(X_train, y_train, X_test, y_test)
# Out:
# Train RMSE: 238114.36314309336
# Test RMSE: 243234.25014980324
# Train R2: 0.5775084222015455
# Test R2: 0.568782614551135
# Train MAE: 156382.26146240602
# Test MAE: 154992.8793844766

# %% [markdown]
# Comparing our model with the baseline model
#
# **Model 1**:
# * **Train RMSE**: 236467.87482500693
# * **Test RMSE**: 242081.30788978518
# * **Train R2**: 0.5833310228392444
# * **Test R2**: 0.5728609089897383
# * **Train MAE**: 155435.64496542394
# * **Test MAE**: 154512.45694916268
#
# **Model 2**:
# * **Train RMSE**: 238114.36314309336
# * **Test RMSE**: 243234.25014980324
# * **Train R2**: 0.5775084222015455
# * **Test R2**: 0.568782614551135
# * **Train MAE**: 156382.26146240602
# * **Test MAE**: 154992.8793844766\
# Our model 2 didn't improve well.

# %% [markdown]
# ### Model 3

# %% [markdown]
# Let's check our continuous variable and do log transformation to improve our model futher.

# %%
# Histogram to check the continuous variable
df3.hist(figsize = (12, 12), bins = 30);

# %% [markdown]
# Our graph clearly shows that the values are skewed. Hence doing log transformation

# %%
# Taking the continous variable 
continuous = ['sqft_above', 'sqft_living', 'sqft_living15', 'price']

# %%
# Log transform and normalize
df_cont = df3[continuous]

# log features
log_names = [f'{column}_log' for column in df_cont.columns]

df_log = np.log(df_cont)
df_log.columns = log_names

# %%
df_log
# Out:
#        sqft_above_log  sqft_living_log  sqft_living15_log  price_log
# 0            7.073270         7.073270           7.200425  12.309982
# 1            7.682482         7.851661           7.432484  13.195614
# 2            6.646391         6.646391           7.908387  12.100712
# 3            6.956545         7.580700           7.215240  13.311329
# 4            7.426549         7.426549           7.495542  13.142166
# ...               ...              ...                ...        ...
# 21592        7.333023         7.333023           7.333023  12.793859
# 21593        7.745003         7.745003           7.512071  12.899220
# 21594        6.927558         6.927558           6.927558  12.904459
# 21595        7.377759         7.377759           7.251345  12.899220
# 21596        6.927558         6.927558           6.927558  12.691580
#
# [21597 rows x 4 columns]

# %%
# concatenating the log transformed variable with our dataframe
df4 = pd.concat([df_log, df3], axis = 1)

# %%
df4
# Out:
#        sqft_above_log  sqft_living_log  sqft_living15_log  price_log  \
# 0            7.073270         7.073270           7.200425  12.309982
# 1            7.682482         7.851661           7.432484  13.195614
# 2            6.646391         6.646391           7.908387  12.100712
# 3            6.956545         7.580700           7.215240  13.311329
# 4            7.426549         7.426549           7.495542  13.142166
# ...               ...              ...                ...        ...
# 21592        7.333023         7.333023           7.333023  12.793859
# 21593        7.745003         7.745003           7.512071  12.899220
# 21594        6.927558         6.927558           6.927558  12.904459
# 21595        7.377759         7.377759           7.251345  12.899220
# 21596        6.927558         6.927558           6.927558  12.691580
#
#        sqft_living  grade  sqft_above  sqft_living15  view  bathrooms  \
# 0             1180      7        1180           1340   0.0       1.00
# 1             2570      7        2170           1690   0.0       2.25
# 2              770      6         770           2720   0.0       1.00
# 3             1960      7        1050           1360   0.0       3.00
# 4             1680      8        1680           1800   0.0       2.00
# ...            ...    ...         ...            ...   ...        ...
# 21592         1530      8        1530           1530   0.0       2.50
# 21593         2310      8        2310           1830   0.0       2.50
# 21594         1020      7        1020           1020   0.0       0.75
# 21595         1600      8        1600           1410   0.0       2.50
# 21596         1020      7        1020           1020   0.0       0.75
#
#           price
# 0      221900.0
# 1      538000.0
# 2      180000.0
# 3      604000.0
# 4      510000.0
# ...         ...
# 21592  360000.0
# 21593  400000.0
# 21594  402101.0
# 21595  400000.0
# 21596  325000.0
#
# [21597 rows x 11 columns]

# %%
# Removing the unlogged column 
df4.drop(['sqft_living', 'sqft_above', 'sqft_living15', 'price'], axis = 1, inplace = True)

# %%
df4
# Out:
#        sqft_above_log  sqft_living_log  sqft_living15_log  price_log  grade  \
# 0            7.073270         7.073270           7.200425  12.309982      7
# 1            7.682482         7.851661           7.432484  13.195614      7
# 2            6.646391         6.646391           7.908387  12.100712      6
# 3            6.956545         7.580700           7.215240  13.311329      7
# 4            7.426549         7.426549           7.495542  13.142166      8
# ...               ...              ...                ...        ...    ...
# 21592        7.333023         7.333023           7.333023  12.793859      8
# 21593        7.745003         7.745003           7.512071  12.899220      8
# 21594        6.927558         6.927558           6.927558  12.904459      7
# 21595        7.377759         7.377759           7.251345  12.899220      8
# 21596        6.927558         6.927558           6.927558  12.691580      7
#
#        view  bathrooms
# 0       0.0       1.00
# 1       0.0       2.25
# 2       0.0       1.00
# 3       0.0       3.00
# 4       0.0       2.00
# ...     ...        ...
# 21592   0.0       2.50
# 21593   0.0       2.50
# 21594   0.0       0.75
# 21595   0.0       2.50
# 21596   0.0       0.75
#
# [21597 rows x 7 columns]

# %% [markdown]
# Checking our data after log transformation

# %%
# histogram plot
df4.hist(figsize = (12, 12), bins = 30);

# %% [markdown]
# Now our data looks way normal from skewed data after log transformation

# %%
# Splitting the train and test data
X = df4.drop('price_log', axis = 1)
y = df4['price_log']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
linear_model(X_train, y_train, X_test, y_test)
# Out:
# Train RMSE: 0.3417654821862211
# Test RMSE: 0.34131400565596115
# Train R2: 0.5800369077132734
# Test R2: 0.575725504061078
# Train MAE: 0.2742282348341492
# Test MAE: 0.27465056572529656

# %% [markdown]
# Comparing our model with the baseline model
#
# **Model 2**:
# * **Train RMSE**: 238114.36314309336
# * **Test RMSE**: 243234.25014980324
# * **Train R2**: 0.5775084222015455
# * **Test R2**: 0.568782614551135
# * **Train MAE**: 156382.26146240602
# * **Test MAE**: 154992.8793844766
#
# **Model 3**:
# * **Train RMSE**: 0.3417654821862211
# * **Test RMSE**: 0.34131400565596115
# * **Train R2**: 0.5800369077132734
# * **Test R2**: 0.575725504061078
# * **Train MAE**: 0.2742282348341492
# * **Test MAE**: 0.27465056572529656
#
# Our model 3 improved well on RMSE value but the R squared value improved but let us try improving the model with better R squared value

# %% [markdown]
# ### Model 4

# %% [markdown]
# Checking for the muliticollinearity to improve our model

# %%
df4.corr()
# Out:
#                    sqft_above_log  sqft_living_log  sqft_living15_log  \
# sqft_above_log           1.000000         0.864979           0.713102
# sqft_living_log          0.864979         1.000000           0.746836
# sqft_living15_log        0.713102         0.746836           1.000000
# price_log                0.586013         0.674802           0.607154
# grade                    0.742869         0.743038           0.689054
# view                     0.157019         0.244804           0.262556
# bathrooms                0.695839         0.762135           0.571796
#
#                    price_log     grade      view  bathrooms
# sqft_above_log      0.586013  0.742869  0.157019   0.695839
# sqft_living_log     0.674802  0.743038  0.244804   0.762135
# sqft_living15_log   0.607154  0.689054  0.262556   0.571796
# price_log           1.000000  0.703720  0.344653   0.551249
# grade               0.703720  1.000000  0.249082   0.665838
# view                0.344653  0.249082  1.000000   0.186016
# bathrooms           0.551249  0.665838  0.186016   1.000000

# %%
corr = df4.corr().abs()
fig, ax = plt.subplots(figsize = (17, 12))
fig.suptitle('Variable Correlations', fontsize = 30, y = .95, fontname = 'Silom')
heatmap = sns.heatmap(corr, cmap = 'Reds', annot = True)
corr
# Out:
#                    sqft_above_log  sqft_living_log  sqft_living15_log  \
# sqft_above_log           1.000000         0.864979           0.713102
# sqft_living_log          0.864979         1.000000           0.746836
# sqft_living15_log        0.713102         0.746836           1.000000
# price_log                0.586013         0.674802           0.607154
# grade                    0.742869         0.743038           0.689054
# view                     0.157019         0.244804           0.262556
# bathrooms                0.695839         0.762135           0.571796
#
#                    price_log     grade      view  bathrooms
# sqft_above_log      0.586013  0.742869  0.157019   0.695839
# sqft_living_log     0.674802  0.743038  0.244804   0.762135
# sqft_living15_log   0.607154  0.689054  0.262556   0.571796
# price_log           1.000000  0.703720  0.344653   0.551249
# grade               0.703720  1.000000  0.249082   0.665838
# view                0.344653  0.249082  1.000000   0.186016
# bathrooms           0.551249  0.665838  0.186016   1.000000

# %% [markdown]
# From our heat map,'sqft_living_log' is highly collinear .hence removing it.

# %%
X = df4.drop(['price_log','sqft_living_log'], axis = 1)
y = df4['price_log']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
linear_model(X_train, y_train, X_test, y_test)
# Out:
# Train RMSE: 0.3513999392706709
# Test RMSE: 0.35286466512965453
# Train R2: 0.5560254312136382
# Test R2: 0.5465232245990275
# Train MAE: 0.28212401085138034
# Test MAE: 0.28455754241841585

# %% [markdown]
# Comparing our model with the baseline model
#
# **Model 3**:
# * **Train RMSE**: 0.3417654821862211
# * **Test RMSE**: 0.34131400565596115
# * **Train R2**: 0.5800369077132734
# * **Test R2**: 0.575725504061078
# * **Train MAE**: 0.2742282348341492
# * **Test MAE**: 0.27465056572529656
#
# **Model 4**:
# * **Train RMSE**: 0.3513999392706709
# * **Test RMSE**: 0.35286466512965453
# * **Train R2**: 0.5560254312136382
# * **Test R2**: 0.5465232245990275
# * **Train MAE**: 0.28212401085138034
# * **Test MAE**: 0.28455754241841585
#  Our model R2 square value is reduced by small amount .

# %% [markdown]
# ### Model 5

# %%
categorical=['bathrooms']

# %%
bathroom_df = np.asarray(df4[['bathrooms']]).reshape(len(df4[['bathrooms']]))

# %%
df5=df4[bathroom_df <= 4]

# %%
df5
# Out:
#        sqft_above_log  sqft_living_log  sqft_living15_log  price_log  grade  \
# 0            7.073270         7.073270           7.200425  12.309982      7
# 1            7.682482         7.851661           7.432484  13.195614      7
# 2            6.646391         6.646391           7.908387  12.100712      6
# 3            6.956545         7.580700           7.215240  13.311329      7
# 4            7.426549         7.426549           7.495542  13.142166      8
# ...               ...              ...                ...        ...    ...
# 21592        7.333023         7.333023           7.333023  12.793859      8
# 21593        7.745003         7.745003           7.512071  12.899220      8
# 21594        6.927558         6.927558           6.927558  12.904459      7
# 21595        7.377759         7.377759           7.251345  12.899220      8
# 21596        6.927558         6.927558           6.927558  12.691580      7
#
#        view  bathrooms
# 0       0.0       1.00
# 1       0.0       2.25
# 2       0.0       1.00
# 3       0.0       3.00
# 4       0.0       2.00
# ...     ...        ...
# 21592   0.0       2.50
# 21593   0.0       2.50
# 21594   0.0       0.75
# 21595   0.0       2.50
# 21596   0.0       0.75
#
# [21331 rows x 7 columns]

# %%
df_cate=pd.get_dummies(df5,columns=categorical,drop_first=True)

# %%
X=df_cate.drop(['price_log'],axis=1)
y=df_cate['price_log']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 42)

# %%
linear_model(X_train, y_train, X_test, y_test)
# Out:
# Train RMSE: 0.33420217863454416
# Test RMSE: 0.34145241899517415
# Train R2: 0.5668054800701774
# Test R2: 0.5687840686619469
# Train MAE: 0.26946727705818463
# Test MAE: 0.27455671534778114

# %% [markdown]
# **Model 4**:
# * **Train RMSE**: 0.3513999392706709
# * **Test RMSE**: 0.35286466512965453
# * **Train R2**: 0.5560254312136382
# * **Test R2**: 0.5465232245990275
# * **Train MAE**: 0.28212401085138034
# * **Test MAE**: 0.28455754241841585
#
# **Model 5**:
# * **Train RMSE**: 0.33420217863454416
# * **Test RMSE**: 0.34145241899517415
# * **Train R2**: 0.5668054800701774
# * **Test R2**: 0.5687840686619469
# * **Train MAE**: 0.26946727705818463
# * **Test MAE**: 0.27455671534778114
#
# There is no big difference in our R2 and RMSE value and hence I am removing the categorical terms.

# %% [markdown]
# ### Model 6

# %% [markdown]
# In our dataset we have 'yr_built', 'yr_renovated' and 'grade' column. Let us check if the house built year and the year renovated has any impact on the price

# %%
sns.pairplot(df, x_vars = ['yr_built', 'yr_renovated','grade'], y_vars = 'price', kind = 'reg');

# %%
sns.scatterplot(x = df['grade'], y = df['price'], data = df)
plt.title('Grade vs. price')
plt.xlabel('Grade')
plt.ylabel('Price (USD)')
plt.show()

# %% [markdown]
# As the grade increases, price value of the house increases.

# %%
# # Scatter plot of sqft living vs price with hue grade
sns.scatterplot(x = df['yr_built'], y = df['price'], hue = df['grade'],data = df)
plt.title('yr_built vs. price')
plt.xlabel('yr_built')
plt.ylabel('Price (USD)')
plt.show()

# %% [markdown]
# From the scatter plot above it's clear that the recently built house has higher grade and hence increase in the price value.

# %%
sns.scatterplot(x = df['yr_renovated'], y = df['price'], hue = df['grade'], data = df)
plt.title('yr_renovated vs. price')
plt.xlabel('yr_renovated')
plt.ylabel('Price (USD)')
plt.show()

# %% [markdown]
# Comparing both the graph above, I am finding the interaction between the 'yr_built and 'price'

# %%
df.sort_values('yr_built', ascending = True)
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 14069 2014-07-28  255500.0         4       1.00         1370     41194
# 14783 2014-10-23  560000.0         4       1.00         1360      5814
# 10973 2015-04-15  730000.0         3       1.75         1650      5000
# 115   2014-11-21  740500.0         3       3.50         4380      6350
# 4693  2014-06-10  558000.0         4       2.00         2180      3870
# ...          ...       ...       ...        ...          ...       ...
# 20235 2015-05-05  771005.0         5       4.50         4000      6713
# 7519  2014-12-31  614285.0         5       2.75         2730      6401
# 14911 2015-04-21  671000.0         4       2.75         1890      1475
# 4150  2015-04-22  631000.0         3       2.25         1670      1396
# 19789 2014-08-01  455000.0         3       1.75         1320      1014
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 14069     1.5         0.0   2.0          5      5        1370            0.0
# 14783     1.5         0.0   0.0          2      6        1360            0.0
# 10973     1.5         0.0   0.0          4      8        1650            0.0
# 115       2.0         0.0   0.0          3      8        2780            0.0
# 4693      1.0         0.0   0.0          3      7        1020         1160.0
# ...       ...         ...   ...        ...    ...         ...            ...
# 20235     2.0         0.0   0.0          3      9        4000            0.0
# 7519      2.0         0.0   0.0          3      8        2730            0.0
# 14911     2.0         0.0   0.0          3      9        1200          690.0
# 4150      2.0         0.0   0.0          3      9        1250          420.0
# 19789     3.0         0.0   0.0          3      9        1320            0.0
#
#        yr_built  yr_renovated zipcode      lat     long  sqft_living15  \
# 14069      1900           0.0   98092  47.2716 -122.144           1590
# 14783      1900           0.0   98122  47.6038 -122.314           1010
# 10973      1900           0.0   98107  47.6743 -122.371           1630
# 115        1900           0.0   98117  47.6981 -122.368           1830
# 4693       1900           0.0   98122  47.6089 -122.303           1520
# ...         ...           ...     ...      ...      ...            ...
# 20235      2015           0.0   98024  47.5254 -121.886           3690
# 7519       2015           0.0   98072  47.7685 -122.160           2520
# 14911      2015           0.0   98199  47.6472 -122.383           1650
# 4150       2015           0.0   98115  47.6814 -122.288           1610
# 19789      2015           0.0   98122  47.6047 -122.305           1380
#
#        sqft_lot15
# 14069       84070
# 14783        5814
# 10973        5000
# 115          6350
# 4693         2580
# ...           ...
# 20235        6600
# 7519         6126
# 14911        1682
# 4150         5191
# 19789        1495
#
# [21597 rows x 20 columns]

# %%
# creating a dictionary to generate new dataframe for each grade category
uniquenames = df.grade.unique()
gradedict = {val : pd.DataFrame() for val in uniquenames}
for key in gradedict.keys():
    gradedict[key] = df[:][df.grade == key]

# %%
gradedict[7]
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13  221900.0         3       1.00         1180      5650
# 1     2014-12-09  538000.0         3       2.25         2570      7242
# 3     2014-12-09  604000.0         4       3.00         1960      5000
# 6     2014-06-27  257500.0         3       2.25         1715      6819
# 7     2015-01-15  291850.0         3       1.50         1060      9711
# ...          ...       ...       ...        ...          ...       ...
# 21567 2014-06-10  399950.0         2       1.00          710      1157
# 21568 2014-12-02  380000.0         3       2.50         1260       900
# 21569 2014-08-28  270000.0         3       2.50         1870      5000
# 21594 2014-06-23  402101.0         2       0.75         1020      1350
# 21596 2014-10-15  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0         1.0         0.0   0.0          3      7        1180            0.0
# 1         2.0         0.0   0.0          3      7        2170          400.0
# 3         1.0         0.0   0.0          5      7        1050          910.0
# 6         2.0         0.0   0.0          3      7        1715            0.0
# 7         1.0         0.0   0.0          3      7        1060            0.0
# ...       ...         ...   ...        ...    ...         ...            ...
# 21567     2.0         0.0   0.0          4      7         710            0.0
# 21568     2.0         0.0   0.0          3      7         940          320.0
# 21569     2.0         0.0   0.0          3      7        1870            0.0
# 21594     2.0         0.0   0.0          3      7        1020            0.0
# 21596     2.0         0.0   0.0          3      7        1020            0.0
#
#        yr_built  yr_renovated zipcode      lat     long  sqft_living15  \
# 0          1955           0.0   98178  47.5112 -122.257           1340
# 1          1951        1991.0   98125  47.7210 -122.319           1690
# 3          1965           0.0   98136  47.5208 -122.393           1360
# 6          1995           0.0   98003  47.3097 -122.327           2238
# 7          1963           0.0   98198  47.4095 -122.315           1650
# ...         ...           ...     ...      ...      ...            ...
# 21567      1943           0.0   98102  47.6413 -122.329           1370
# 21568      2007           0.0   98116  47.5621 -122.384           1310
# 21569      2009           0.0   98042  47.3339 -122.055           2170
# 21594      2009           0.0   98144  47.5944 -122.299           1020
# 21596      2008           0.0   98144  47.5941 -122.299           1020
#
#        sqft_lot15
# 0            5650
# 1            7639
# 3            5000
# 6            6819
# 7            9711
# ...           ...
# 21567        1173
# 21568        1415
# 21569        5399
# 21594        2007
# 21596        1357
#
# [8974 rows x 20 columns]

# %%
# selecting yr_built column from each grade dataframe
uniquenames = df.grade.unique()    
yr_builtdict = {val : gradedict[val].yr_built.values.reshape(-1, 1) for val in uniquenames}

# %%
yr_builtdict[7]
# Out:
# array([[1955],
#        [1951],
#        [1965],
#        ...,
#        [2009],
#        [2009],
#        [2008]])

# %%
# creating list for linear regression
reg_list = ['regression_3', 'regression_4', 'regression_5', 'regression_6', 'regression_7', 'regression_8', 'regression_9', 'regression_10', 'regression_11', 'regression_12', 'regression_13']

# %%
# creating a dictionary to initialize linear regression for each grade value
uniquenames=df.grade.unique()
reg_dict = {val : LinearRegression() for val in uniquenames}

# %%
reg_dict
# Out:
# {7: LinearRegression(),
#  6: LinearRegression(),
#  8: LinearRegression(),
#  11: LinearRegression(),
#  9: LinearRegression(),
#  5: LinearRegression(),
#  10: LinearRegression(),
#  12: LinearRegression(),
#  4: LinearRegression(),
#  3: LinearRegression(),
#  13: LinearRegression()}

# %%
# function for creating the model
def linearRegression(list_):
    for num in list_:
        reg_dict = {val : LinearRegression() for val in list_}
    return reg_dict

# %%
# function to fit our regression model
def model_fit(list_):
    for num in list_:
        val = reg_dict[num].fit(yr_builtdict[num], gradedict[num].price)
    return val

# %%
# function to predict our regression model
def model_predict(list_):
    for num in list_:
        val1 = reg_dict[num].predict(yr_builtdict[num])
    return val1

# %%
# function to find coefficient of the model
def model_coef(list_):
    for num in list_:
        print(reg_dict[num].coef_)

# %%
linearRegression(uniquenames)
# Out:
# {7: LinearRegression(),
#  6: LinearRegression(),
#  8: LinearRegression(),
#  11: LinearRegression(),
#  9: LinearRegression(),
#  5: LinearRegression(),
#  10: LinearRegression(),
#  12: LinearRegression(),
#  4: LinearRegression(),
#  3: LinearRegression(),
#  13: LinearRegression()}

# %%
model_fit(uniquenames)
# Out:
# LinearRegression()

# %%
model_predict(uniquenames)
# Out:
# array([3377244.53409831, 4457780.38104163, 3336211.52725236,
#        3390922.20304696, 3691830.91991726, 4621912.40842543,
#        4307326.02260649, 3377244.53409831, 3377244.53409831,
#        3445632.87884156, 3555054.23043076, 3869640.6162497 ,
#        3431955.20989291])

# %%
model_coef(uniquenames)
# Out:
# [-2332.32979903]
# [-1586.35393954]
# [-3492.56926511]
# [-9321.03418737]
# [-5364.81001601]
# [-243.19741074]
# [-8203.75581432]
# [1580.23967095]
# [1878.27184246]
# [0.]
# [-13677.66894865]

# %%
# creating dictionary to predict the value of the regression model
uniquenames = df.grade.unique() 
uniquenames.sort()
for num in uniquenames:
        pred_dict = {val : reg_dict[val].predict(yr_builtdict[val]) for val in uniquenames}

# %%
# function to plot the interaction graph
def plot_function(list_):
    plt.figure(figsize=(30, 25))
    for num in list_:
        plt.scatter(yr_builtdict[num], gradedict[num].price,alpha = 0.3, label = 'grade ='+str(num))
        plt.plot(yr_builtdict[num], pred_dict[num], linewidth=2)
    plt.ylabel('price')
    plt.xlabel('yr_built')
    plt.legend();
    return plt.show()

# %%
plot_function(uniquenames)

# %% [markdown]
# From the above graph ,there is an interaction between the 'grade' and 'yr_built'

# %%
#selecting the 'yr_built and 'yr_renovated' column from the dataframe 
df6 = df[['yr_built', 'yr_renovated']]

# %%
# concatinating yr_built and 'yr_renovated' to the current dataframe
df7 = pd.concat([df4, df6], axis = 1)

# %%
# splitting the date for train and test set
X = df7.drop('price_log', axis = 1)
y = df7['price_log']

# %%
# applying interactions to 'yr_built and 'grade' by multiplying them
X_interact_2 = X.copy()
X_interact_2['grade_year'] = X['yr_built'] * X['grade']

# %%
X_interact_2
# Out:
#        sqft_above_log  sqft_living_log  sqft_living15_log  grade  view  \
# 0            7.073270         7.073270           7.200425      7   0.0
# 1            7.682482         7.851661           7.432484      7   0.0
# 2            6.646391         6.646391           7.908387      6   0.0
# 3            6.956545         7.580700           7.215240      7   0.0
# 4            7.426549         7.426549           7.495542      8   0.0
# ...               ...              ...                ...    ...   ...
# 21592        7.333023         7.333023           7.333023      8   0.0
# 21593        7.745003         7.745003           7.512071      8   0.0
# 21594        6.927558         6.927558           6.927558      7   0.0
# 21595        7.377759         7.377759           7.251345      8   0.0
# 21596        6.927558         6.927558           6.927558      7   0.0
#
#        bathrooms  yr_built  yr_renovated  grade_year
# 0           1.00      1955           0.0       13685
# 1           2.25      1951        1991.0       13657
# 2           1.00      1933           0.0       11598
# 3           3.00      1965           0.0       13755
# 4           2.00      1987           0.0       15896
# ...          ...       ...           ...         ...
# 21592       2.50      2009           0.0       16072
# 21593       2.50      2014           0.0       16112
# 21594       0.75      2009           0.0       14063
# 21595       2.50      2004           0.0       16032
# 21596       0.75      2008           0.0       14056
#
# [21597 rows x 9 columns]

# %%
# splitting data for train and test 
X = X_interact_2
y = df7['price_log']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
linear_model(X_train, y_train, X_test, y_test)
# Out:
# Train RMSE: 0.3132980216188752
# Test RMSE: 0.3193145255976609
# Train R2: 0.647085067318093
# Test R2: 0.6286563030309209
# Train MAE: 0.25003103955551087
# Test MAE: 0.2554643842175556

# %% [markdown]
# Comparing our model with the baseline model
#
# **Model 5**:
# * **Train RMSE**: 0.3513999392706709
# * **Test RMSE**: 0.35286466512965453
# * **Train R2**: 0.5560254312136382
# * **Test R2**: 0.5465232245990275
# * **Train MAE**: 0.26946727705818463
# * **Test MAE**: 0.27455671534778114
#
# **Model 6**:
# * **Train RMSE**: 0.3132980216188752
# * **Test RMSE**: 0.3193145255976609
# * **Train R2**: 0.647085067318093
# * **Test R2**: 0.6286563030309209
# * **Train MAE**: 0.25003103955551087
# * **Test MAE**: 0.2554643842175556
# Our new model looks better in terms of both R2 value and RMSE value.

# %% [markdown]
# Let us futher check for any interactions in our data

# %%
X = df7.drop('price_log', axis = 1)
y = df7['price_log']
baseline = 0.5560254312136382

# %%
# Function to check for interaction in our dataset
from itertools import combinations
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
interactions = []
# Combination function for the X values
feat_combinations = combinations(X.columns, 2)
regression=LinearRegression()
crossvalidation = KFold(n_splits=3, shuffle=True, random_state=1)
# duplicate of X dataframe
data_3 = X.copy()
# Applying interaction term for each combinations
for i, (a, b) in enumerate(feat_combinations):
    data_3['interaction'] = data_3[a] * data_3[b]
    score = np.mean(cross_val_score(regression, data_3, y, scoring='r2', cv=crossvalidation))
    if score > baseline:
        interactions.append((a, b, round(score,3)))
    
    if i % 50 == 0:
        print(i)
            
print('Top 3 interactions: %s' %sorted(interactions, key=lambda inter: inter[2], reverse=True)[:3])
# Out:
# 0
# Top 3 interactions: [('sqft_living15_log', 'yr_built', 0.645), ('sqft_living15_log', 'grade', 0.644), ('sqft_above_log', 'sqft_living_log', 0.643)]

# %%
# Define 'tiers' of sqft
sqft = np.asarray(df7[['sqft_living_log']]).reshape(len(df7[['sqft_living_log']]))
high_sqft = df7[sqft > np.percentile(sqft, 67)]
med_sqft = df7[(sqft > np.percentile(sqft, 33)) & (sqft <= np.percentile(sqft, 67))]
low_sqft = df7[sqft <= np.percentile(sqft, 33)]

# %%
high_sqft = df7[sqft > np.percentile(sqft, 67)]
med_sqft = df7[(sqft > np.percentile(sqft, 33)) & (sqft <= np.percentile(sqft, 67))]
low_sqft = df7[sqft <= np.percentile(sqft, 33)]

# %%
regression_1 = LinearRegression()
regression_2 = LinearRegression()
regression_3 = LinearRegression()

yr_built1 = high_sqft['yr_built'].values.reshape(-1, 1)
yr_built2 = med_sqft['yr_built'].values.reshape(-1, 1)
yr_built3 = low_sqft['yr_built'].values.reshape(-1, 1)

regression_1.fit(yr_built1, high_sqft['price_log'])
regression_2.fit(yr_built2, med_sqft['price_log'])
regression_3.fit(yr_built3, low_sqft['price_log'])

# Make predictions using the testing set
pred_1 = regression_1.predict(yr_built1)
pred_2 = regression_2.predict(yr_built2)
pred_3 = regression_3.predict(yr_built3)

# The coefficients
print(regression_1.coef_)
print(regression_2.coef_)
print(regression_3.coef_)
# Out:
# [-0.00203552]
# [-0.00328888]
# [-0.0006947]

# %%
# Plot outputs
plt.figure(figsize = (10, 6))

plt.scatter(yr_built1, high_sqft['price_log'],  color = 'blue', alpha = 0.3, label = 'high_sqft')
plt.scatter(yr_built2, med_sqft['price_log'],  color = 'red', alpha = 0.3, label = 'med_sqft')
plt.scatter(yr_built3, low_sqft['price_log'],  color = 'orange', alpha = 0.3, label = 'low_sqft')

plt.plot(yr_built1, pred_1, color = 'blue', linewidth = 2)
plt.plot(yr_built2, pred_2, color = 'red', linewidth = 2)
plt.plot(yr_built3, pred_3, color = 'orange', linewidth = 2)
plt.ylabel('price_log')
plt.xlabel('yr_built')
plt.legend();

# %% [markdown]
# So the graph doesn't show any interactions between the variables. Comparing all the models, Model 5 has given a satisfactory result and hence I am considering Model 5 as my final model.

# %% [markdown]
# Now let us check our coefficient for interpretation

# %%
# splitting data for train and test 
X = X_interact_2
y = df7['price_log']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
# scaling our train and test data
scaler=StandardScaler()
scaler.fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
# Initializing regression for our final model
linreg6=LinearRegression()

# %%
# fitting our model
linreg6.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
# predicting our model value
train_pred=linreg6.predict(X_train_scaled)
test_pred=linreg6.predict(X_test_scaled)

# %%
# dictionary for our model coefficient values
dict(zip(X.columns, linreg6.coef_))
# Out:
# {'sqft_above_log': -0.021770055297525837,
#  'sqft_living_log': 0.10892603292839172,
#  'sqft_living15_log': 0.06681428281492817,
#  'grade': -0.32348332202041746,
#  'view': 0.04967993185827171,
#  'bathrooms': 0.08242836295741171,
#  'yr_built': -0.22420941567862027,
#  'yr_renovated': 0.005777342119279377,
#  'grade_year': 0.6174644154354602}

# %% [markdown]
# Checking our final model for the Linear Regression Assumptions

# %%
residuals_train=y_train - train_pred
residuals_test=y_test - test_pred

# %%
# lm = LinearRegression()
# lm.fit(X,y)
params = np.append(linreg6.intercept_,linreg6.coef_)
predictions = linreg6.predict(X_train_scaled)

newX = pd.DataFrame({"Constant":np.ones(len(X))}).join(pd.DataFrame(X))
MSE = (sum((y_train-predictions)**2))/(len(newX)-len(newX.columns))

# Note if you don't want to use a DataFrame replace the two lines above with
# newX = np.append(np.ones((len(X),1)), X, axis=1)
# MSE = (sum((y-predictions)**2))/(len(newX)-len(newX[0]))

var_b = MSE*(np.linalg.inv(np.dot(newX.T,newX)).diagonal())
sd_b = np.sqrt(var_b)
ts_b = params/ sd_b

# p_values =[2*(1-stats.t.cdf(np.abs(i),(len(newX)-len(newX[0])))) for i in ts_b]
p_values =[2*(1-stats.t.cdf(np.abs(i),(len(newX)-len(newX.columns)-1))) for i in ts_b]
sd_b = np.round(sd_b,3)
ts_b = np.round(ts_b,3)
p_values = np.round(p_values,3)
params = np.round(params,4)
# cols=np.append(val for val in X.columns)
# np.linalg.inv(np.dot(newX.T,newX)).diagonal())

myDF3 = pd.DataFrame()
myDF3["Coefficients"],myDF3["Standard Errors"],myDF3["t values"],myDF3["Probabilities"] = [params,sd_b,ts_b,p_values]
print(myDF3)
# Out:
#    Coefficients  Standard Errors   t values  Probabilities
# 0       13.0498            0.849     15.363          0.000
# 1       -0.0218            0.010     -2.287          0.022
# 2        0.1089            0.011      9.984          0.000
# 3        0.0668            0.009      7.367          0.000
# 4       -0.3235            0.112     -2.884          0.004
# 5        0.0497            0.003     19.150          0.000
# 6        0.0824            0.004     19.989          0.000
# 7       -0.2242            0.000   -521.373          0.000
# 8        0.0058            0.000   1088.385          0.000
# 9        0.6175            0.000  10885.872          0.000

# %%
params = np.append(linreg6.intercept_,linreg6.coef_)
predictions = linreg6.predict(X_train_scaled)
newX = pd.DataFrame({"Constant":np.ones(len(X))}).join(pd.DataFrame(X))
MSE = (sum((y_train-predictions)**2))/(len(newX)-len(newX.columns))
var_b = MSE*(np.linalg.inv(np.dot(newX.T,newX)).diagonal())
sd_b = np.sqrt(var_b)

# %%
plt.scatter(train_pred, residuals_train, alpha=.75)
plt.scatter(test_pred, residuals_test, color='g', alpha=.75)
plt.axhline(y=0, color='black')
plt.title('Residuals for Linear Regression Model')
plt.ylabel('Residuals')
plt.xlabel('Predicted Values')
plt.show()

# %% [markdown]
# From the above residual plot, our final model is Homoscedastic

# %%
ax1 = plt.subplot(221)
res = stats.probplot(residuals_train, plot=plt)

# %% [markdown]
# From the above probplot, our model is normally distributed

# %%
sns.pairplot(df7, x_vars = ['sqft_living_log', 'bathrooms'], y_vars = 'price_log', kind = 'reg');

# %% [markdown]
# From the above pairplot, our model shows a linear relationship between the target variables(price) and response variables(sqft_living and bathrooms)

# %%
corr = df7.corr().abs()
fig, ax = plt.subplots(figsize = (17, 12))
fig.suptitle('Variable Correlations', fontsize = 30, y = .95, fontname = 'Silom')
heatmap = sns.heatmap(corr, cmap = 'Reds', annot = True)
corr
# Out:
#                    sqft_above_log  sqft_living_log  sqft_living15_log  \
# sqft_above_log           1.000000         0.864979           0.713102
# sqft_living_log          0.864979         1.000000           0.746836
# sqft_living15_log        0.713102         0.746836           1.000000
# price_log                0.586013         0.674802           0.607154
# grade                    0.742869         0.743038           0.689054
# view                     0.157019         0.244804           0.262556
# bathrooms                0.695839         0.762135           0.571796
# yr_built                 0.451397         0.349689           0.333819
# yr_renovated             0.023434         0.047366           0.002211
#
#                    price_log     grade      view  bathrooms  yr_built  \
# sqft_above_log      0.586013  0.742869  0.157019   0.695839  0.451397
# sqft_living_log     0.674802  0.743038  0.244804   0.762135  0.349689
# sqft_living15_log   0.607154  0.689054  0.262556   0.571796  0.333819
# price_log           1.000000  0.703720  0.344653   0.551249  0.080583
# grade               0.703720  1.000000  0.249082   0.665838  0.447865
# view                0.344653  0.249082  1.000000   0.186016  0.054452
# bathrooms           0.551249  0.665838  0.186016   1.000000  0.507173
# yr_built            0.080583  0.447865  0.054452   0.507173  1.000000
# yr_renovated        0.106867  0.015623  0.090339   0.047177  0.202555
#
#                    yr_renovated
# sqft_above_log         0.023434
# sqft_living_log        0.047366
# sqft_living15_log      0.002211
# price_log              0.106867
# grade                  0.015623
# view                   0.090339
# bathrooms              0.047177
# yr_built               0.202555
# yr_renovated           1.000000

# %% [markdown]
# From the above heat map, our model is having a multicollinearity between the varibales

# %% [markdown]
# ## Interpret

# %%
params = np.append(linreg6.intercept_,linreg6.coef_)
predictions = linreg6.predict(X_train_scaled)

newX = pd.DataFrame({"Constant":np.ones(len(X))}).join(pd.DataFrame(X))
MSE = (sum((y_train-predictions)**2))/(len(newX)-len(newX.columns))

# Note if you don't want to use a DataFrame replace the two lines above with
# newX = np.append(np.ones((len(X),1)), X, axis=1)
# MSE = (sum((y-predictions)**2))/(len(newX)-len(newX[0]))

var_b = MSE*(np.linalg.inv(np.dot(newX.T,newX)).diagonal())
sd_b = np.sqrt(var_b)
ts_b = params/ sd_b

# p_values =[2*(1-stats.t.cdf(np.abs(i),(len(newX)-len(newX[0])))) for i in ts_b]
p_values =[2*(1-stats.t.cdf(np.abs(i),(len(newX)-len(newX.columns)-1))) for i in ts_b]
sd_b = np.round(sd_b,3)
ts_b = np.round(ts_b,3)
p_values = np.round(p_values,3)
params = np.round(params,4)
# cols=np.append(val for val in X.columns)
# np.linalg.inv(np.dot(newX.T,newX)).diagonal())

myDF3 = pd.DataFrame()
myDF3["Coefficients"],myDF3["Standard Errors"],myDF3["t values"],myDF3["Probabilities"] = [params,sd_b,ts_b,p_values]
print(myDF3)
# Out:
#    Coefficients  Standard Errors   t values  Probabilities
# 0       13.0498            0.849     15.363          0.000
# 1       -0.0218            0.010     -2.287          0.022
# 2        0.1089            0.011      9.984          0.000
# 3        0.0668            0.009      7.367          0.000
# 4       -0.3235            0.112     -2.884          0.004
# 5        0.0497            0.003     19.150          0.000
# 6        0.0824            0.004     19.989          0.000
# 7       -0.2242            0.000   -521.373          0.000
# 8        0.0058            0.000   1088.385          0.000
# 9        0.6175            0.000  10885.872          0.000

# %% [markdown]
# **Model coefficients:**\
# **sqft_above_log:** -0.021770055297525837\
# **sqft_living_log:** 0.10892603292839172\
# **sqft_living15_log:** 0.06681428281492817\
# **grade:** -0.32348332202041746\
# **view:** 0.04967993185827171\
# **bathrooms:** 0.08242836295741171\
# **yr_built:** -0.22420941567862027\
# **yr_renovated:** 0.005777342119279377\
# **grade_year:** 0.6174644154354602

# %%
plt.scatter(x = df['sqft_living'], y = df['price'], alpha = 0.3)
plt.xlabel("Square Footage")
plt.ylabel("Price")
plt.savefig("./images/sqft.png")

# %%
plt.scatter(x = df['bathrooms'], y = df['price'], alpha = 0.3, label = 'Data Points')
plt.xlabel("bathroom")
plt.ylabel("Price")
plt.savefig("./images/bathroom.png")

# %% [markdown]
# Among the 9 features, the model interpretation is done for 2 parameters.
# * Square Footage Living
# * Bathroom
#
# The coefficient p_value of our target and response variable is 0. So they are statistically significant. The target variable (price) and the response variable 'sqft_living' and 'bathrooms' are log transformed.
#
# Coefficient of 'Sqft-living' is 0.108.  Hence for  every 1% increase of sqft_living,price increase by 0.11%.\
# Therefore for every 0.11% increase in sqft_living,our price increase by (1.11^0.11-1)*100=1.15% .\
# Similarly for every 0.08% increase in bathroom ,our price increase by (1.08^0.08-1)*100=0.61%

# %% [markdown]
# Train RMSE: 0.3132980216188752\
# Test RMSE: 0.3193145255976609\
# Train R2: 0.647085067318093\
# Test R2: 0.6286563030309209\
# Train MAE: 0.25003103955551087\
# Test MAE: 0.2554643842175556
# * The model RMSE for the train and test set are similar which indicates that our model will perform well on different data
# * The model R2 value is 0.647 which is 64% of price variation is explained by our model
# * The model MAE value is 0.25 which is 25% off from the mean value.
#
# Since the model is log transformed , our interpretation cannot be done in USD as it is unit free

# %% [markdown]
# ## Conclusion:

# %% [markdown]
# If you are looking for housing that won't make your bank account fragile, then go for the housing with minimal bathroom so that you could share them and it's advisable to shrink on squarefootage that would make our house purchase a very cost effective one.

# %% [markdown]
# ## Next Step:

# %% [markdown]
# The model does have some limitations to satisfy regression assumptions.
# * Our model has a multicolinear relationship between the variables. Hence futher processing needs to be done on removing the multicollinearity
# * Our interaction graph shows that there are many house with higher grade having lesser price value. Hence it could be of the geographical locations of whether the houses are located in the heart of the city or away from it. So futher analysis and investigations needs to be done on those criteria using the zipcode locations.
# * This model have not handled any outliers. Future work involves handling those outliers and check the model prediction on removing outliers.

# %% [markdown]
# ## For More Information:

# %% [markdown]
# See the full analysis in the Jupyter Notebook or review this presentation.
#
# For additional info,contact Janaki @janakipurushothamman@gmail.com
